# %%
# Feature Scaling

# Feature Scaling is a data preprocessing technique used in Machine Learning to bring all features (variables) to a similar scale. It prevents features with larger values from dominating those with smaller values.

# Why is Feature Scaling Important?

# Consider a dataset with:

# Age: 18–60
# Salary: 20,000–1,000,000

# Algorithms that rely on distance calculations (e.g., KNN, K-Means, SVM, Gradient Descent) may give more importance to Salary because of its larger magnitude.
