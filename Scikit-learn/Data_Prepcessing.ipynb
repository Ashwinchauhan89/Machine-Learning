# %%
import pandas as pd

# %%
data = {
    "name" : ["Ashwin","Kajal","Sagar"],
     "age" : [20,None,123],
    "gender" : ["m","f","m"]
}
df = pd.DataFrame(data)
print

# %%
# Out:
# {'name': ['Ashwin', 'Kajal', 'Sagar'], 'age': [20, None, 123], 'gender': ['m', 'f', 'm']}
