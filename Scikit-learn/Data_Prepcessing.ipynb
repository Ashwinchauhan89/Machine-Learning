# %%
import pandas as pd

# %%
data = {
    "name" : ["Ashwin","Kajal","Sagar"],
     "age" : [20,None,123],
    "gender" : ["m","f","m"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#      name    age gender
# 0  Ashwin   20.0      m
# 1   Kajal    NaN      f
# 2   Sagar  123.0      m
