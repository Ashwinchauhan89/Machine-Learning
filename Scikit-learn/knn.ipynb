# %%
# K-Nearest Neighbors (KNN) - Complete Example
# What is KNN?

# KNN (K-Nearest Neighbors) is a Supervised Machine Learning Algorithm used for:

# Classification
# Regression

# It predicts the output based on the nearest neighbors.

# %%
# | Study Hours | Result |
# | ----------- | ------ |
# | 1           | 0      |
# | 2           | 0      |
# | 3           | 0      |
# | 4           | 1      |
# | 5           | 1      |
# | 6           | 1      |

# 0 = Fail
# 1 = Pass

# %%
from sklearn.neighbors import KNeighborsClassifier

# Features
X = [[1], [2], [3], [4], [5], [6]]

# Labels
y = [0, 0, 0, 1, 1, 1]

# Create Model
model = KNeighborsClassifier(n_neighbors=3)

# Train Model
model.fit(X, y)

# Prediction
result = model.predict([[5]])

print("Prediction:", result)
# Out:
# Prediction: [1]

# %%
# Study Hours = 5
# Result = Pass



# n_neighbors=3

# K = 3

# The model will check the 3 nearest neighbors before making a prediction.
