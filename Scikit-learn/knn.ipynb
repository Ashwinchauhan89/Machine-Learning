# %%
# K-Nearest Neighbors (KNN) - Complete Example
# What is KNN?

# KNN (K-Nearest Neighbors) is a Supervised Machine Learning Algorithm used for:

# Classification
# Regression

# It predicts the output based on the nearest neighbors.

# %%
# | Study Hours | Result |
# | ----------- | ------ |
# | 1           | 0      |
# | 2           | 0      |
# | 3           | 0      |
# | 4           | 1      |
# | 5           | 1      |
# | 6           | 1      |

# 0 = Fail
# 1 = Pass

# %%
from sklearn.neighbors import KNeighborsClassifier

# Features
X = [[1], [2], [3], [4], [5], [6]]

# Labels
y = [0, 0, 0, 1, 1, 1]

# Create Model
model = KNeighborsClassifier(n_neighbors=)

# Train Model
model.fit(X, y)

# Prediction
result = model.predict([[5]])

print("Prediction:", result)
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[8], line 13
#      10 model = KNeighborsClassifier(n_neighbors=0)
#      12 # Train Model
# ---> 13 model.fit(X, y)
#      15 # Prediction
#      16 result = model.predict([[5]])
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1329, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1324 partial_fit_and_fitted = (
#    1325     fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1326 )
#    1328 if not global_skip_validation and not partial_fit_and_fitted:
# -> 1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
#    1336     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:492, in BaseEstimator._validate_params(self)
#     484 def _validate_params(self):
#     485     """Validate types and values of constructor parameters
#     486
#     487     The expected type and values must be defined in the `_parameter_constraints`
#    (...)    490     accepted constraints.
#     491     """
# --> 492     validate_parameter_constraints(
#     493         self._parameter_constraints,
#     494         self.get_params(deep=False),
#     495         caller_name=self.__class__.__name__,
#     496     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:98, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      92 else:
#      93     constraints_str = (
#      94         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      95         f" {constraints[-1]}"
#      96     )
# ---> 98 raise InvalidParameterError(
#      99     f"The {param_name!r} parameter of {caller_name} must be"
#     100     f" {constraints_str}. Got {param_val!r} instead."
#     101 )
#
# InvalidParameterError: The 'n_neighbors' parameter of KNeighborsClassifier must be an int in the range [1, inf) or None. Got 0 instead.
