# %%
import torch

# %%
# image \\\

# con2D


# reLU

# pool


# Con2d

# relU



# pool

# fatlen


# Input

#       raw pixel  ===> pixel  ===> noise removed  ===> Reduce dheight and widht  ==> Flatten (list of coverting number)   ==> Probotity   


Thid bis part Conventaional Netural Nettur
