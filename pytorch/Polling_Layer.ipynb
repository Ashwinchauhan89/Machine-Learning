# %%
 # poling are used to minimize te dimension of te image>

# %%
import torch
import torch.nn as nn

# %%
x = torch.rand(1,3,23,29)
print(x)
# Out:
# tensor([[[[0.3561, 0.0111, 0.1704,  ..., 0.5538, 0.1786, 0.8219],
#           [0.7476, 0.9047, 0.2935,  ..., 0.6299, 0.5757, 0.2722],
#           [0.8301, 0.2409, 0.3981,  ..., 0.3905, 0.7666, 0.6518],
#           ...,
#           [0.8654, 0.4314, 0.0466,  ..., 0.4177, 0.4477, 0.8668],
#           [0.4214, 0.7089, 0.8826,  ..., 0.1784, 0.6080, 0.3567],
#           [0.7629, 0.1187, 0.5430,  ..., 0.5146, 0.9037, 0.5283]],
#
#          [[0.2884, 0.5320, 0.4856,  ..., 0.5902, 0.5896, 0.2006],
#           [0.1663, 0.0065, 0.8479,  ..., 0.2987, 0.4815, 0.2517],
#           [0.4606, 0.5170, 0.1212,  ..., 0.9963, 0.8592, 0.5543],
#           ...,
#           [0.8908, 0.8684, 0.6842,  ..., 0.8399, 0.5046, 0.0845],
#           [0.0207, 0.7357, 0.1437,  ..., 0.9101, 0.1675, 0.2635],
#           [0.2995, 0.2859, 0.8665,  ..., 0.2143, 0.6833, 0.8769]],
#
#          [[0.3950, 0.4034, 0.7200,  ..., 0.9659, 0.3633, 0.9660],
#           [0.6043, 0.2054, 0.4329,  ..., 0.8451, 0.2484, 0.8615],
# ...

# %%
# pool = nn.Maxpool2d(kernel_size =2)

# %%
pool = nn.MaxPool2d(kernel_size =2)
