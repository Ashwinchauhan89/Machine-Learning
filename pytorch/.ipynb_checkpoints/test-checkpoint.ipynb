# %%
import torch

# %%
x = torch.rand(10, 3)
print(x)
# Out:
# tensor([[0.8938, 0.7669, 0.8745],
#         [0.4586, 0.9493, 0.3356],
#         [0.4082, 0.4510, 0.5682],
#         [0.2097, 0.4339, 0.6823],
#         [0.9163, 0.4582, 0.6817],
#         [0.9871, 0.1582, 0.4796],
#         [0.3416, 0.8877, 0.3112],
#         [0.6221, 0.3258, 0.3809],
#         [0.3777, 0.9670, 0.1302],
#         [0.7139, 0.5118, 0.6873]])
